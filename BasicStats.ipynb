# %%
#Import Python Libraries 
#    similar to library() function in R
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_main = pd.read_csv("Salaries.csv")

# %%
df_main.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df_main.tail(60)
# Out:
#          rank discipline  phd  service     sex  salary
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# 20   AsstProf          B    4        4    Male   92000
# 21       Prof          A   33       30    Male  103106
# 22   AsstProf          A    4        2    Male   73000
# 23   AsstProf          A    2        0    Male   85000
# 24       Prof          A   30       23    Male   91100
# 25       Prof          B   35       31    Male   99418
# 26       Prof          A   38       19    Male  148750
# 27       Prof          A   45       43    Male  155865
# 28   AsstProf          B    7        2    Male   91300
# 29       Prof          B   21       20    Male  123683
# 30  AssocProf          B    9        7    Male  107008
# 31       Prof          B   22       21    Male  155750
# 32       Prof          A   27       19    Male  103275
# 33       Prof          B   18       18    Male  120000
# ...

# %%
type(df_main)
# Out:
# pandas.core.frame.DataFrame

# %%
type(pd)
# Out:
# module

# %%
type(pd)
# Out:
# module

# %%
df_main.info
# Out:
# <bound method DataFrame.info of          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df_main['salary'].dtype
# Out:
# dtype('int64')

# %%
df_main.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df_main.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df_main.columns[3]
# Out:
# 'service'

# %%
df_main.index(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2791f811861c> in <module>
# ----> 1 df_main.index(4)
#
# TypeError: 'RangeIndex' object is not callable

# %%
df_main.set_index("index")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-b664a852b5e6> in <module>
# ----> 1 df_main.set_index("index")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['index'] are in the columns"

# %%
df_main.index = range(1, 79, 1)

# %%
df_main
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          B   56       49    Male  186960
# 2        Prof          A   12        6    Male   93000
# 3        Prof          A   23       20    Male  110515
# 4        Prof          A   40       31    Male  131205
# 5        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 74       Prof          B   18       10  Female  105450
# 75  AssocProf          B   19        6  Female  104542
# 76       Prof          B   17       17  Female  124312
# 77       Prof          A   28       14  Female  109954
# 78       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df_main.rename(columns = {' ':'Index', inplace = True)
# Out:
#   File "<ipython-input-50-c9d1d7833d58>", line 1
#     df_main.rename(columns = {' ':'Index', inplace = True)
#                                                    ^
# SyntaxError: invalid syntax

# %%
df_main.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df_main.index.names = ['slNo']

# %%
df_main
# Out:
#            rank discipline  phd  service     sex  salary
# slNo
# 1          Prof          B   56       49    Male  186960
# 2          Prof          A   12        6    Male   93000
# 3          Prof          A   23       20    Male  110515
# 4          Prof          A   40       31    Male  131205
# 5          Prof          B   20       18    Male  104800
# ...         ...        ...  ...      ...     ...     ...
# 74         Prof          B   18       10  Female  105450
# 75    AssocProf          B   19        6  Female  104542
# 76         Prof          B   17       17  Female  124312
# 77         Prof          A   28       14  Female  109954
# 78         Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df_main.head('slNo' == 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-b2ce656b9da9> in <module>
# ----> 1 df_main.head('slNo' == 4)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in head(self, n)
#    5065         5     parrot
#    5066         """
# -> 5067         return self.iloc[:n]
#    5068
#    5069     @final
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1479     def _getitem_axis(self, key, axis: int):
#    1480         if isinstance(key, slice):
# ...

# %%
df_main.iloc[[2, 3, 5]]
# Out:
#       rank discipline  phd  service   sex  salary
# slNo
# 3     Prof          A   23       20  Male  110515
# 4     Prof          A   40       31  Male  131205
# 6     Prof          A   20       20  Male  122400

# %%
df_main.iloc[2]
# Out:
# rank            Prof
# discipline         A
# phd               23
# service           20
# sex             Male
# salary        110515
# Name: 2, dtype: object

# %%
df_main.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df_sub = df_main.groupby(['sex','rank'])

# %%
df_sub.groupby('salary').filter(lambda group:group.size>90000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d96c4d363aa1> in <module>
# ----> 1 df_sub.groupby('salary').filter(lambda group:group.size>90000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
df_sub['salary' > 90000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-7002e82a83b6> in <module>
# ----> 1 df_sub['salary'>90000]
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
df_sub

# %%
df_sub.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# ...

# %%
df_test = df_main[ df_main['salary'] > 90000]

# %%
df_test.head(100)
# Out:
#            rank discipline  phd  service     sex  salary
# slNo
# 1          Prof          B   56       49    Male  186960
# 2          Prof          A   12        6    Male   93000
# 3          Prof          A   23       20    Male  110515
# 4          Prof          A   40       31    Male  131205
# 5          Prof          B   20       18    Male  104800
# 6          Prof          A   20       20    Male  122400
# 8          Prof          A   18       18    Male  126300
# 9          Prof          A   29       19    Male   94350
# 11         Prof          B   39       33    Male  128250
# 12         Prof          B   23       23    Male  134778
# 14         Prof          B   35       33    Male  162200
# 15         Prof          B   25       19    Male  153750
# 16         Prof          B   17        3    Male  150480
# 18     AsstProf          B    4        0    Male   92000
# 19         Prof          A   19        7    Male  107300
# ...

# %%
df_main.groupby(['sex','rank'], sort=False)[['salary']]

# %%
df_main.groupby(['sex','rank'], sort=False)[['salary']].df_main[df_main.salary > 90000]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-46abec0dcdd7> in <module>
# ----> 1 df_main.groupby(['sex','rank'], sort=False)[['salary']].df_main[df_main.salary > 90000]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'df_main'

# %%
df_main.groupby(['sex','rank'])[df_main['salary'] > 90000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-22ea939a42ea> in <module>
# ----> 1 df_main.groupby(['sex','rank'])[df_main['salary'] > 90000].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266                     set(key).difference(self.obj.columns)  # type: ignore[attr-defined]
#     267                 )
# --> 268                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     269             return self._gotitem(list(key), ndim=2)
#     270
#
# KeyError: 'Columns not found: False, True'

# %%
df_sub2 = df_main.groupby(['sex','rank'])

# %%
df_sub2.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# ...

# %%
df = pd.read_csv("Salaries.csv")

# %%
df_new = df.groupby(['sex','rank'])

# %%
df_new.query('salary > 90000').head(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-df2fd9d32f86> in <module>
# ----> 1 df_new.query('salary > 90000').head(100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'query'

# %%
df_new.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-8bbc59140d11> in <module>
# ----> 1 df_new.type
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'type'

# %%
df_sub3 = df_sub2[ df_main['salary'] > 90000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-5e29090e72df> in <module>
# ----> 1 df_sub3 = df_sub2[ df_main['salary'] > 90000]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     266                     set(key).difference(self.obj.columns)  # type: ignore[attr-defined]
#     267                 )
# --> 268                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     269             return self._gotitem(list(key), ndim=2)
#     270
#
# KeyError: 'Columns not found: False, True'

# %%
df_main.query('salary > 90000').head(100)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
df_sub3.head(100)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
type(df_new)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
f_filter = df_new['salary']==90000
print(df_new[f_filter])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-3093a321fcb2> in <module>
#       1 f_filter = df_new['salary']==90000
# ----> 2 print(df_new[f_filter])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# ...

# %%
df_sub3 = df_sub2[ df_sub2['salary'] == 90000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-a86b0808f8fc> in <module>
# ----> 1 df_sub3 = df_sub2[ df_sub2['salary'] == 90000]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: False'

# %%
df_sub4 = df_main[df_main['rank'] == 'Prof']
df_sub4 = df_sub4[df_sub4['salary'] > 90000]
df_sub4.head(100)
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# 3   Prof          A   40       31    Male  131205
# 4   Prof          B   20       18    Male  104800
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 8   Prof          A   29       19    Male   94350
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 18  Prof          A   19        7    Male  107300
# 19  Prof          A   29       27    Male  150500
# 21  Prof          A   33       30    Male  103106
# 24  Prof          A   30       23    Male   91100
# 25  Prof          B   35       31    Male   99418
# ...

# %%
type(df_sub4)
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby(['sex','rank'], sort=False)[['salary']].mean()

# %%
df_new1 = df.groupby(['sex','rank'], sort=False)[['salary']].count()

# %%
df_new1.head(100)
# Out:
#     salary
# 0   186960
# 1    93000
# 2   110515
# 3   131205
# 4   104800
# ..     ...
# 73  105450
# 74  104542
# 75  124312
# 76  109954
# 77  109646
#
# [78 rows x 1 columns]

# %%
df = pd.read_csv("Salaries.csv")

# %%
df.groupby(['sex','rank'], sort=False)

# %%
df_rank = df.groupby('rank')

# %%
df_sex = df.groupby('sex')

# %%
df_sex.head(20)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df_ranksex = df.groupby(['rank','sex'])['salary'].reset_index()
#df_sub = df_ranksex[ df_ranksex['salary'] > 90000]
#df_sub
#g1 = df1.groupby( [ "Name", "City"] ).count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-07976e4d1504> in <module>
# ----> 1 df_ranksex = df.groupby(['rank','sex'])['salary'].reset_index()
#       2 #df_sub = df_ranksex[ df_ranksex['salary'] > 90000]
#       3 #df_sub
#       4 #g1 = df1.groupby( [ "Name", "City"] ).count().reset_index()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'reset_index'

# %%
grouped_df = df.groupby('sex')

# %%
grouped_df.head(20)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.groupby(['sex','rank'], sort=False)

# %%
df_ranksex = pd.DataFrame(grouped_df)

# %%
type(df_ranksex)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ranksex.head()
# Out:
#            0                                                  1
# 0  AssocProf           rank discipline  phd  service     sex...
# 1   AsstProf          rank discipline  phd  service     sex ...
# 2       Prof      rank discipline  phd  service     sex  sal...

# %%
df_ranksex = df_ranksex[ df_ranksex['salary'] > 90000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-83289459711a> in <module>
# ----> 1 df_ranksex = df_ranksex[ df_ranksex['salary'] > 90000]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# ...

# %%
df_ranksex.head(10)
# Out:
#         rank     sex  discipline  phd  service  salary
# 0  AssocProf  Female          10   10       10      10
# 1  AssocProf    Male           3    3        3       3
# 2   AsstProf  Female          11   11       11      11
# 3   AsstProf    Male           8    8        8       8
# 4       Prof  Female          18   18       18      18
# 5       Prof    Male          28   28       28      28

# %%
df_test = df[ df['salary'] > 90000]
df_test.head(100)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# 17   AsstProf          B    4        0    Male   92000
# 18       Prof          A   19        7    Male  107300
# 19       Prof          A   29       27    Male  150500
# ...

# %%
df_rank.head(20)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df = pd.read_csv("Salaries.csv")

# %%
df.gt(90000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-19ab467fc6cf> in <module>
# ----> 1 df.gt(90000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level)
#     449         self, other = align_method_FRAME(self, other, axis, flex=True, level=level)
#     450
# --> 451         new_data = self._dispatch_frame_op(other, op, axis=axis)
#     452         return self._construct_result(new_data)
#     453
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _dispatch_frame_op(self, right, func, axis)
#    6006         if not is_list_like(right):
#    6007             # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 6008             bm = self._mgr.apply(array_op, right=right)
#    6009             return type(self)(bm)
#    6010
#
# ...

# %%
df_gp = df.groupby(['rank'], sort=False)[['salary']].mean()

# %%
df_gp = df.groupby(['sex','rank','salary'], sort=True)[['phd']].count()

# %%
df_test = pd.DataFrame(df_gp)

# %%
df_test.query('salary > 90000').head(100)
# Out:
#                          phd
# sex    rank      salary
# Female AssocProf 103613    1
#                  103750    1
#                  103994    1
#                  104542    1
#                  109650    1
#        AsstProf  92000     1
#                  97032     1
#        Prof      90450     1
#                  91000     1
#                  105000    1
#                  105450    1
#                  109646    1
#                  109954    1
#                  111512    1
#                  116450    1
#                  117555    1
#                  122960    1
#                  124312    1
#                  127512    1
#                  129000    1
#                  137000    1
#                  140096    1
#                  144651    1
#                  151768    1
#                  161101    1
# Male   AssocProf 107008    1
#                  119800    1
#        AsstProf  91000     1
#                  91300     1
#                  92000     2
# ...

# %%
df_new = df.groupby(['rank', 'sex']).query('salary > 90000').head(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-188-44c89ab2aa54> in <module>
# ----> 1 df_new = df.groupby(['rank', 'sex']).query('salary > 90000').head(100)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'query'

# %%
grouped_df = df.groupby( [ "rank", "sex"] )

pd.DataFrame(grouped_df.size().reset_index(name = "Group_Count"))
# Out:
#         rank     sex  Group_Count
# 0  AssocProf  Female           10
# 1  AssocProf    Male            3
# 2   AsstProf  Female           11
# 3   AsstProf    Male            8
# 4       Prof  Female           18
# 5       Prof    Male           28

# %%
df_new.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# ...

# %%
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new = pd.DataFrame(df_new)

# %%
df_new.head()
# Out:
#            0                                                  1
# 0  AssocProf           rank discipline  phd  service     sex...
# 1   AsstProf          rank discipline  phd  service     sex ...
# 2       Prof      rank discipline  phd  service     sex  sal...

# %%
df_new.query('salary > 90000').head(100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     200             if self.has_resolvers:
# --> 201                 return self.resolvers[key]
#     202
#
# C:\ProgramData\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# C:\ProgramData\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: 'salary'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_sub = df[ df['salary'] > 120000]
df_sub.head(100)
