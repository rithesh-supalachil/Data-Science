# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StudentDetails2.csv")

# %%
df.head(101)
# Out:
#        RollNo              Name Course                        EmailID  \
# 0   212200101       Clint Riley    MCA      clint_riley4632@yahoo.com
# 1   212200102     Sylvia Palmer    MCA  sylvia_palmer9828@grannar.com
# 2   212200103        Kate Power    MCA      kate_power9136@ovock.tech
# 3   212200104        Rufus Fall    MCA       rufus_fall4446@corti.com
# 4   212200105    Adelaide James    MCA   adelaide_james7262@atink.com
# ..        ...               ...    ...                            ...
# 95  212210140      Kieth Tanner  MTech      kieth_tanner999@sheye.org
# 96  212210141        Chad Clark  MTech       chad_clark2387@brety.org
# 97  212210142       Carla Avery  MTech     carla_avery7990@guentu.biz
# 98  212210143  Priscilla Walker  MTech  priscilla_walker403@atink.com
# 99  212210144      Rick Bristow  MTech   rick_bristow4127@ubusive.com
#
#                Address  Python  Java  DataScience  ImageProcess  \
# ...

# %%
df.describe()
# Out:
#              RollNo      Python        Java  DataScience  ImageProcess  \
# count  1.000000e+02  100.000000  100.000000   100.000000    100.000000
# mean   2.122045e+08   63.880000   61.480000    62.560000     60.360000
# std    4.985905e+03   21.381707   21.483129    23.033274     23.459624
# min    2.122001e+08   25.000000   25.000000    25.000000     25.000000
# 25%    2.122001e+08   45.750000   44.500000    41.000000     39.000000
# 50%    2.122002e+08   62.000000   62.500000    60.500000     59.500000
# 75%    2.122101e+08   83.250000   80.000000    82.500000     80.500000
# max    2.122101e+08  100.000000  100.000000    99.000000    100.000000
#
#        CloudComputing       ADBMS
# count      100.000000  100.000000
# mean        63.750000   61.850000
# std         24.012781   19.228753
# min         25.000000   26.000000
# 25%         41.750000   47.750000
# 50%         62.000000   61.000000
# 75%         86.250000   76.250000
# max        100.000000   98.000000

# %%
df.rename(columns = {'Subject1':'Python', 'Subject2':'Java', 'Subject3':'DataScience','Subject4':'ImageProcess', 'Subject5':'CloudComputing', 'Subject6':'ADBMS'}, inplace = True)
